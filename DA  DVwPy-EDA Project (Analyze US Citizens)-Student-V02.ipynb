# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 32561 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df0 = pd.read_csv("adult_eda.csv")
df = df0.copy()

# missing_values = ["n/a", "na", "--", "?"]  # Replacing non-standard missing values with NaN
# df1 = pd.read_csv("adult_eda.csv", na_values = missing_values)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Removing Duplicates

# %%
# Check if the Dataset have any Duplicate

df.duplicated().sum()
# Out:
# 24

# %%
# Drop Duplicates

df.drop_duplicates(inplace = True)

# %%
# Check the shape of the Dataset

df.shape  # 24 rows deleted
# Out:
# (32537, 15)

# %%
# Check the statistical values of features
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education-num   31735 non-null  float64
#  5   marital-status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital-gain    32537 non-null  int64
#  11  capital-loss    32537 non-null  int64
#  12  hours-per-week  32537 non-null  int64
#  13  native-country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 4.0+ MB

# %%
# Rename the columns' names for easy use

df.rename({"education-num": "education_num",
           "marital-status": "marital_status",
           "capital-gain": "capital_gain", 
           "capital-loss": "capital_loss", 
           "hours-per-week": "hours_per_week", 
           "native-country": "native_country"},axis=1, inplace=True)

# %%
# Check the sum of Missing Values per column

df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values

df.isnull().sum() / len(df) * 100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   31735 non-null  float64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 4.0+ MB

# %%
df.describe(include="O").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
# Assign the Columns (Features) of object data type as "object_col"


# object_col = ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'native_country', 'salary']

object_col = list(filter(lambda x : df[x].dtype == "object", df.columns))
object_col
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'salary']

# %%
# Look at the value counts of columns that have object datatype

for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Check if the Dataset has any Question Mark "?"

print("Number of '?'s in the dataset:", "\n")

for col in df.columns:
    if (df[col] == '?').sum() > 0:
        print(f"{col} : {(df[col] == '?').sum()}")  # len(df[df[col] == '?']) can replace (df[col] == '?').sum()
# Out:
# Number of '?'s in the dataset:
#
# workclass : 1836
# occupation : 1843
# native_country : 582

# %%
# Check if the Dataset has any NULL values. Alternative to df.isnull().sum()

print("Number of NULL values in the dataset:", "\n")

for col in df.columns:
    if df[col].isnull().sum() > 0:
        print(f"{col} : {df[col].isnull().sum()}")
# Out:
# Number of NULL values in the dataset:
#
# education_num : 802
# relationship : 5064

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# # Salary (Target Feature)

# %%
# Check the count of person in each "salary" levels and visualize it with a countplot

df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots()

sns.countplot(x = df.salary);
ax.bar_label(ax.containers[0], size=10);

# %%
perc_income = df.salary.value_counts() / len(df) * 100
perc_income
# Out:
# <=50K   75.907
# >50K    24.093
# Name: salary, dtype: float64

# %%
# Check the percentage of person in each "salary" levels and visualize it with a pieplot

plt.figure(figsize=(6, 6))

plt.pie(x=perc_income.values,
        labels = perc_income.index,
        explode=[0.1, 0],
        shadow=True,
        autopct="%.1f%%",
       textprops={"fontsize": 11},
       colors=["lightskyblue", "gold"])

plt.title("Percentage of Income-Levels", fontsize=15, pad=10)

plt.show()

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :** About three quarters (76 %) of US citizens earn 50,000 USD or less per year, while 24% earn more  than 50,000 USD per year.

# %% [markdown]
# # Numeric Features

# %% [markdown]
# ## age

# %%
# Check the boxplot to see extreme values

sns.boxplot(x=df.age);

# %%
# Check the histplot/kdeplot to see distribution of feature

sns.histplot(x=df.age, bins=20, kde=True);

# %%
# Check the statistical values

df.describe()[["age"]].T
# Out:
#         count   mean    std    min    25%    50%    75%    max
# age 32537.000 38.586 13.638 17.000 28.000 37.000 48.000 90.000

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels

sns.boxplot(data=df, x="salary", y="age");

# %%
sns.histplot(data=df, x="age", bins=20, hue="salary", kde=True);

# %%
sns.kdeplot(data=df, x="age", hue="salary", shade=True);

# %%
# Check the statistical values by "salary" levels

df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. The ages above 78 are extreme values. So, those observations may need to be reconsidered.
# 2. 50% of the data has been collected from people between 28 (Q1) years and 48(Q3) years old and the meadian age is 37 years.
# 3. The mean and median values of people in the group earning >50k (44.3 and 44.0) are considerably higher than those of the group earning <=50k (36.8 and 34.0). That means, in average, older people earn more than younger people.

# %% [markdown]
# ## fnlwgt

# %%
# Check the boxplot to see extreme values

sns.boxplot(x=df.fnlwgt);

# %%
# Check the histplot/kdeplot to see distribution of feature

sns.kdeplot(data=df, x="fnlwgt", shade=True);

# %%
# Check the statistical values

df.describe()[["fnlwgt"]]
# Out:
#            fnlwgt
# count   32537.000
# mean   189780.849
# std    105556.471
# min     12285.000
# 25%    117827.000
# 50%    178356.000
# 75%    236993.000
# max   1484705.000

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels

sns.boxplot(data=df, x="salary", y="fnlwgt");

# %%
sns.kdeplot(data=df, x="fnlwgt", hue="salary", shade=True);

# %%
# Check the statistical values by "salary" levels

df.groupby("salary").describe()["fnlwgt"]
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# The two income groups (<=50k salary and >50k salary) show similar centreal tendency measures (mean and median) and similar standard deviations. That means the data almost equally represnts both income groups and can be relibale regarding its representation of the two different groups.

# %% [markdown]
# ## capital_gain

# %%
# Check the boxplot to see extreme values

sns.boxplot(x=df.capital_gain);

# %%
# Check the histplot/kdeplot to see distribution of feature

sns.kdeplot(data=df, x="capital_gain", shade=True);

# %%
# Check the statistical values

df.describe()[["capital_gain"]]
# Out:
#        capital_gain
# count     32537.000
# mean       1078.444
# std        7387.957
# min           0.000
# 25%           0.000
# 50%           0.000
# 75%           0.000
# max       99999.000

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels

sns.boxplot(data=df, x="salary", y="capital_gain");

# %%
sns.kdeplot(data=df, x="capital_gain", hue="salary", shade=True);

# %%
# Check the statistical values by "salary" levels

df.groupby("salary").describe()["capital_gain"]
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %%
# Check the statistical values by "salary" levels for capital_gain not equal the zero

df[df.capital_gain != 0].groupby("salary").describe()["capital_gain"]
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %%
# EXTRA: The percentage of people with non-zero capital gain or loss ()

len(df[(df.capital_gain !=0) | (df.capital_loss !=0)]) / len(df) * 100
# Out:
# 13.003657374681133

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. First of all, only 13% of people in this survey have non-zero gain or loss. That means 87% have not made any investment. Therefore, the data doesn't produce valuable insight about the capital gain/loss in general.
# 2. Looking at the non-zero capital gain, as it can be expected, the mean and median values of high-income group (18731 and 7896) are significantly higher than those of low-income group (3553 and 3273). A simple reason could be the fact that people in high income group could invest more money more frequently which can potentially lead to more gain.

# %% [markdown]
# ## capital_loss

# %%
# Check the boxplot to see extreme values

sns.boxplot(x=df.capital_loss);

# %%
# Check the histplot/kdeplot to see distribution of feature

sns.kdeplot(data=df, x="capital_loss", shade=True);

# %%
# Check the statistical values

df.describe()[["capital_loss"]]
# Out:
#        capital_loss
# count     32537.000
# mean         87.368
# std         403.102
# min           0.000
# 25%           0.000
# 50%           0.000
# 75%           0.000
# max        4356.000

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels

sns.boxplot(data=df, x="salary", y="capital_loss");

# %%
sns.kdeplot(data=df, x="capital_loss", hue="salary", shade=True);

# %%
# Check the statistical values by "salary" levels

df.groupby("salary").describe()["capital_loss"]
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %%
# Check the statistical values by "salary" levels for capital_gain not equal the zero

df[df.capital_loss != 0].groupby("salary").describe()["capital_loss"]
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
#
# 1. First of all, only 13% of people in this survey have non-zero gain or loss. That means 87% have not made any investment. Therefore, the data doesn't produce valuable insight about the capital gain/loss in general.
# 2. Looking at the non-zero capital loss, it wouldn't be surprising to see the mean and median values of high-income group being significantly higher than those of low-income group (as more investment can result in not only more gain but also more loss). However thsese values in the two groups are quite similar. This can be interpreted as "In average, people in high-income group have not made significantly bad investments."

# %% [markdown]
# ## hours_per_week

# %%
# Check the boxplot to see extreme values

sns.boxplot(x=df.hours_per_week);

# %%
# Check the histplot/kdeplot to see distribution of feature

sns.kdeplot(data=df, x="hours_per_week", shade=True);

# %%
# Check the statistical values

df.describe()[["hours_per_week"]]
# Out:
#        hours_per_week
# count       32537.000
# mean           40.440
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels

sns.boxplot(data=df, x="salary", y="hours_per_week");

# %%
sns.kdeplot(data=df, x="hours_per_week", hue="salary", shade=True);

# %%
# Check the statistical values by "salary" levels

df.groupby("salary").describe()["hours_per_week"]
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. Both mean and median values of weekly working hours are 40 and at least 50% of the participants in the survey work between 40 and 45 hours per week.However, there are many outliers on both sides of the box plot. That means there are many people who work less than 40 hours a week or more than 45 hours a week:
#
# 2. Looking at the data by salary level, in average (considering the mean values), people in high-income group appear to be working 7 hours more than people in low-level income group (45 hrs and 38 hrs respectively).
#
# 3. Similarly, at least 25% of people in high income group work 50 hours or more (Q3), while this value is only 40 or more hours among low-income group.
#
# 4. In summary, it is clear that people in high income group work more than people in low-incme group in terms of working hours per week.

# %%
# See the relationship between each numeric features by target feature (salary) in one plot basically

sns.pairplot(df, hue="salary", palette="viridis", corner=True);

# %% [markdown]
# # Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# #### Detect the similarities between these features by comparing unique values

# %%
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df.education_num.unique()
# Out:
# array([13.,  9.,  7., 14.,  5., 10., 12., nan,  4., 16., 11., 15.,  3.,
#         6.,  2.,  1.,  8.])

# %%
df.education.value_counts(dropna=False)
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df.education_num.value_counts(dropna=False)
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.groupby("education")["education_num"].value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %%
df.groupby("education_num")["education"].value_counts(dropna=False)
# Out:
# education_num  education
# 1.000          Preschool          49
# 2.000          1st-4th           159
# 3.000          5th-6th           329
# 4.000          7th-8th           630
# 5.000          9th               503
# 6.000          10th              916
# 7.000          11th             1146
# 8.000          12th              424
# 9.000          HS-grad         10208
# 10.000         Some-college     7089
# 11.000         Assoc-voc        1343
# 12.000         Assoc-acdm       1044
# 13.000         Bachelors        5245
# 14.000         Masters          1686
# 15.000         Prof-school       559
# 16.000         Doctorate         405
# Name: education, dtype: int64

# %% [markdown]
# #### Visualize the count of person in each categories for these features (education, education_num) separately

# %%
sns.countplot(data=df, x="education");
plt.xticks(rotation=90);

# %%
sns.countplot(data=df, x="education_num");

# %% [markdown]
# #### Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot

# %%
df.groupby("education")["salary"].value_counts(dropna=False)
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
sns.countplot(data=df, x="education", hue="salary");

plt.xticks(rotation=90);

# %%
df.groupby("education_num")["salary"].value_counts(dropna=False)
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
sns.countplot(data=df, x="education_num", hue="salary");

# %% [markdown]
# #### Visualize the boxplot of "education_num" feature by "salary" levels

# %%
sns.boxplot(data=df, x="salary", y="education_num");

# %% [markdown]
# #### Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# # By using "mapping_education" def function above, create a new column named "education_summary"

df["edu_level"] = df.education.transform(mapping_education)

# %% [markdown]
# #### Visualize the count of person in each categories for these new education levels (high, medium, low)

# %%
df.edu_level.value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: edu_level, dtype: int64

# %%
sns.countplot(data=df, x="edu_level");

# %% [markdown]
# #### Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot

# %%
df.groupby("edu_level")["salary"].value_counts()
# Out:
# edu_level           salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="edu_level", hue="salary");

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately

# %%
perc_edu_level = df.groupby("edu_level")["salary"].value_counts(normalize=True)
perc_edu_level
# Out:
# edu_level           salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,9));


ax[0].pie(perc_edu_level[0:2],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[0].set_title(perc_edu_level.index[0][0],fontsize=12)
ax[0].set_ylabel("salary", fontsize=10);

ax[1].pie(perc_edu_level[2:4],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[1].set_title(perc_edu_level.index[2][0],fontsize=12)
ax[1].set_ylabel("salary", fontsize=10);


ax[2].pie(perc_edu_level[4:6],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[2].set_title(perc_edu_level.index[4][0],fontsize=12)
ax[2].set_ylabel("salary", fontsize=10);

# %% [markdown]
# #### Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["edu_level"].value_counts()
# Out:
# salary  edu_level
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: edu_level, dtype: int64

# %%
sns.countplot(data=df, x="salary", hue="edu_level");

# %% [markdown]
# #### Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately

# %%
perc_edu_by_salary = df.groupby("salary")["edu_level"].value_counts(normalize=True)
perc_edu_by_salary
# Out:
# salary  edu_level
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: edu_level, dtype: float64

# %%
perc_edu_by_salary.index[0:3]
# Out:
# MultiIndex([('<=50K', 'medium_level_grade'),
#             ('<=50K',   'high_level_grade'),
#             ('<=50K',    'low_level_grade')],
#            names=['salary', 'edu_level'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,6));


ax[0].pie(perc_edu_by_salary[0:3],
            labels=perc_edu_by_salary.index[0:3],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue", "lightgreen"]);
ax[0].set_title("<=50",fontsize=15)
ax[0].set_ylabel("edu_level", fontsize=10);

ax[1].pie(perc_edu_by_salary[3:6],
            labels=perc_edu_by_salary.index[3:6],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue", "lightgreen"]);
ax[1].set_title(">50",fontsize=15)
ax[1].set_ylabel("edu_level", fontsize=10);

# %%
df_perc_edu_by_salary = pd.DataFrame(df.groupby("salary")["edu_level"].value_counts(normalize=True))
df_perc_edu_by_salary.rename({"edu_level": "percentage"}, axis=1, inplace=True)
df_perc_edu_by_salary.reset_index(level=[0,1], inplace=True)
df_perc_edu_by_salary.sort_values(["salary", "edu_level"], inplace=True)
df_perc_edu_by_salary
# Out:
#   salary           edu_level  percentage
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 0  <=50K  medium_level_grade       0.670
# 3   >50K    high_level_grade       0.499
# 5   >50K     low_level_grade       0.031
# 4   >50K  medium_level_grade       0.470

# %%
df_perc_edu_by_salary[0:3].percentage
# Out:
# 1   0.168
# 2   0.162
# 0   0.670
# Name: percentage, dtype: float64

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,6));


ax[0].pie(df_perc_edu_by_salary[0:3].percentage,
            labels=["high", "low", "medium"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue", "lightgreen"]);
ax[0].set_title("<=50K",fontsize=12)
ax[0].set_ylabel("percentage", fontsize=10);

ax[1].pie(df_perc_edu_by_salary[3:6].percentage,
            labels=["high", "low", "medium"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue", "lightgreen"]);
ax[1].set_title(">50K",fontsize=12)
ax[1].set_ylabel("percentage", fontsize=10);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. The two feautures ''education' and 'education_num' represent the same thing one firs being the categorical name and the second being the numerical name for participants' education levels.
# 2. More than half of the participants are from medium-level education group (HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm)
# 3. Although, the number of participants from medium-level education group are significantly higher than the other groups, the percentage of hight-level education groups is still is the greatest in high-salary (>50K) group. That means education level has significant effect on salary level.

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# #### Detect the similarities between these features by comparing unique values

# %%
print(df.marital_status.unique())
print("--"*30)
print(df.relationship.unique())
# Out:
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# ------------------------------------------------------------
# ['Not-in-family' 'Husband' 'Wife' nan 'Unmarried' 'Other-relative']

# %%
df.marital_status.value_counts(dropna=False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

df.relationship.fillna("Unknown", inplace=True)
df.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# Unknown            5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.groupby("marital_status")["relationship"].value_counts()
# Out:
# marital_status         relationship
# Divorced               Not-in-family      2403
#                        Unmarried          1600
#                        Unknown             328
#                        Other-relative      110
# Married-AF-spouse      Wife                 12
#                        Husband               9
#                        Other-relative        1
#                        Unknown               1
# Married-civ-spouse     Husband           13178
#                        Wife               1556
#                        Other-relative      124
#                        Unknown              95
#                        Not-in-family        17
# Married-spouse-absent  Not-in-family       211
#                        Unmarried           130
#                        Unknown              45
#                        Other-relative       32
# Never-married          Not-in-family      4694
#                        Unknown            4481
# ...

# %% [markdown]
# **Assessment :**
#
# The variables "marital_status" and "relationship" are closely realted and they should be anslysed together.
#
# However, it is worth to notice that 130 participants identified themselves as both "Married-spouse-absent" under maritial status and "unmarried" under relationship status.

# %% [markdown]
# #### Visualize the count of person in each categories

# %%
sns.countplot(data=df, x="marital_status");
plt.xticks(rotation=45);

# %% [markdown]
# #### Check the count of person in each "salary" levels by categories and visualize it with countplot

# %%
df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="marital_status", hue="salary");
plt.xticks(rotation=45);

# %% [markdown]
# #### Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

df["marital_status_summary"] = df.marital_status.transform(mapping_marital_status)

df.marital_status_summary.value_counts(dropna=False)
# Out:
# unmarried    17126
# married      15411
# Name: marital_status_summary, dtype: int64

# %% [markdown]
# #### Visualize the count of person in each categories for these new marital status (married, unmarried)

# %%
sns.countplot(data=df, x="marital_status_summary");

# %% [markdown]
# #### Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot

# %%
df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="marital_status_summary", hue="salary");

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately

# %%
perc_salary_by_marital = df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
perc_salary_by_marital
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,6));

ax[0].pie(perc_salary_by_marital[0:2],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[0].set_title("married",fontsize=12)
ax[0].set_ylabel("salary", fontsize=10);

ax[1].pie(perc_salary_by_marital[2:4],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[1].set_title("unmarried",fontsize=12)
ax[1].set_ylabel("salary", fontsize=10);

# %% [markdown]
# #### Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["marital_status_summary"].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(data=df, x="salary", hue="marital_status_summary");

# %% [markdown]
# #### Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately

# %%
perc_marital_by_salary = df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
perc_marital_by_salary
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df_perc_marital_by_salary = pd.DataFrame(df.groupby("salary")["marital_status_summary"].value_counts(normalize=True))
df_perc_marital_by_salary.rename({"marital_status_summary": "percentage"}, axis=1, inplace=True)
df_perc_marital_by_salary.reset_index(level=[0,1], inplace=True)
df_perc_marital_by_salary.sort_values(["salary", "marital_status_summary"], inplace=True)
df_perc_marital_by_salary
# Out:
#   salary marital_status_summary  percentage
# 1  <=50K                married       0.351
# 0  <=50K              unmarried       0.649
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,6));


ax[0].pie(df_perc_marital_by_salary[0:2].percentage,
            labels=["married", "unmarried"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue", "lightgreen"]);
ax[0].set_title("<=50K",fontsize=12)
ax[0].set_ylabel("percentage", fontsize=10);

ax[1].pie(df_perc_marital_by_salary[2:4].percentage,
            labels=["married", "unmarried"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue", "lightgreen"]);
ax[1].set_title(">50K",fontsize=12)
ax[1].set_ylabel("percentage", fontsize=10);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. The number of married participants are slightly higher than the number of unmarried participants.
# 2. About 44% of married participants earn more than 50K annulay, while only 14% of unmarried participants earn 50K per year. This clearlu shows that married people earn more than unmarried people. One possible reason could be the fact that most unmarried people are young and less-experineced.

# %% [markdown]
# ## workclass

# %% [markdown]
# #### Check the count of person in each categories and visualize it with countplot

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
sns.countplot(data=df, x="workclass");
plt.xticks(rotation=90);

# %% [markdown]
# #### Replace the value "?" to the value "Unknown"

# %%
df["workclass"].replace("?", "Unknown", inplace=True)

df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# #### Check the count of person in each "salary" levels by workclass groups and visualize it with countplot

# %%
df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="workclass", hue="salary");
plt.xticks(rotation=90);

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot

# %%
df_salary_by_workclass = pd.DataFrame(df.groupby("workclass")["salary"].value_counts(normalize=True))
df_salary_by_workclass.rename({"salary": "percentage"}, axis=1, inplace=True)
df_salary_by_workclass.reset_index(level=[0,1], inplace=True)
df_salary_by_workclass.sort_values(["workclass", "salary"], inplace=True)
df_salary_by_workclass
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 8       Self-emp-inc  <=50K       0.443
# 7       Self-emp-inc   >50K       0.557
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
fig,ax = plt.subplots()

sns.barplot(data=df_salary_by_workclass, x="workclass", y="percentage", hue="salary");

plt.xticks(rotation=90)

for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.2f');

# %% [markdown]
# #### Check the count of person in each workclass groups by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
sns.countplot(data=df, x="salary", hue="workclass");
plt.legend(loc="upper center");

# %% [markdown]
# #### Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot

# %%
df_workclass_by_salary = pd.DataFrame(df.groupby("salary")["workclass"].value_counts(normalize=True))
df_workclass_by_salary.rename({"workclass": "percentage"}, axis=1, inplace=True)
df_workclass_by_salary.reset_index(level=[0,1], inplace=True)
df_workclass_by_salary.sort_values(["salary", "workclass"], inplace=True)
df_workclass_by_salary
# Out:
#    salary         workclass  percentage
# 5   <=50K       Federal-gov       0.024
# 3   <=50K         Local-gov       0.060
# 8   <=50K      Never-worked       0.000
# 0   <=50K           Private       0.717
# 6   <=50K      Self-emp-inc       0.020
# 1   <=50K  Self-emp-not-inc       0.074
# 4   <=50K         State-gov       0.038
# 2   <=50K           Unknown       0.067
# 7   <=50K       Without-pay       0.001
# 13   >50K       Federal-gov       0.047
# 12   >50K         Local-gov       0.079
# 9    >50K           Private       0.633
# 11   >50K      Self-emp-inc       0.079
# 10   >50K  Self-emp-not-inc       0.092
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
fig,ax = plt.subplots(figsize=(14, 6))

sns.barplot(data=df_workclass_by_salary, x="salary", y="percentage", hue="workclass");
plt.legend(loc="upper left")
for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.3f');

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. About 70% of participants work in private sector.
# 2. In every workclass group, the percenatge of people eraning <=50K is higher than those earning >50K. However, those percentages are very close to each other in self-emp-inc group (56% and 44% respectively)

# %% [markdown]
# ## occupation

# %% [markdown]
# #### Check the count of person in each categories and visualize it with countplot

# %%
df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
sns.countplot(data=df, x="occupation");
plt.xticks(rotation=90);

# %% [markdown]
# #### Replace the value "?" to the value "Unknown"

# %%
df.occupation.replace("?", "Unknownn", inplace=True)

df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknownn             1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %% [markdown]
# #### Check the count of person in each "salary" levels by occupation groups and visualize it with countplot

# %%
df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
sns.countplot(data=df, x="occupation", hue="salary");
plt.xticks(rotation=90);

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot

# %%
df_salary_by_occupation = pd.DataFrame(df.groupby("occupation")["salary"].value_counts(normalize=True))
df_salary_by_occupation.rename({"salary": "percentage"}, axis=1, inplace=True)
df_salary_by_occupation.reset_index(level=[0,1], inplace=True)
df_salary_by_occupation.sort_values(["occupation", "salary"], inplace=True)
df_salary_by_occupation
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
fig,ax = plt.subplots(figsize=(14, 6))

sns.barplot(data=df_salary_by_occupation, x="occupation", y="percentage", hue="salary");

plt.xticks(rotation=90)

for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.2f');

# %% [markdown]
# #### Check the count of person in each occupation groups by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["occupation"].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknownn             1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknownn              191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
sns.countplot(data=df, x="salary", hue="occupation");

# %% [markdown]
# #### Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot

# %%
df_occupation_by_salary = pd.DataFrame(df.groupby("salary")["occupation"].value_counts(normalize=True))
df_occupation_by_salary.rename({"occupation": "percentage"}, axis=1, inplace=True)
df_occupation_by_salary.reset_index(level=[0,1], inplace=True)
df_occupation_by_salary.sort_values(["salary", "occupation"], inplace=True)
df_occupation_by_salary
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 14  <=50K       Armed-Forces       0.000
# 1   <=50K       Craft-repair       0.128
# 5   <=50K    Exec-managerial       0.085
# 10  <=50K    Farming-fishing       0.036
# 8   <=50K  Handlers-cleaners       0.052
# 6   <=50K  Machine-op-inspct       0.071
# 2   <=50K      Other-service       0.128
# 13  <=50K    Priv-house-serv       0.006
# 4   <=50K     Prof-specialty       0.092
# 12  <=50K    Protective-serv       0.018
# 3   <=50K              Sales       0.108
# 11  <=50K       Tech-support       0.026
# 9   <=50K   Transport-moving       0.052
# 7   <=50K           Unknownn       0.067
# 19   >50K       Adm-clerical       0.065
# 28   >50K       Armed-Forces       0.000
# 18   >50K       Craft-repair       0.119
# 15   >50K    Exec-managerial       0.251
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 22   >50K  Machine-op-inspct       0.032
# ...

# %%
fig,ax = plt.subplots(figsize=(18, 6), dpi=80)

sns.barplot(data=df_occupation_by_salary, x="salary", y="percentage", hue="occupation");
plt.legend(loc="upper right")

for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.3f');

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
#
# The highest in-group percentage of people earning <=50K are in the groups Pric-house-serv, Other-service and Handlers-cleaners (99%, 96% and 94% respectively), while the highest in-group percentage of people earning >50K are in the groups Exec-managerial and Prof-speciality (48% and 45% respectively).

# %% [markdown]
# ## race

# %% [markdown]
# #### Check the count of person in each categories and visualize it with countplot

# %%
df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
sns.countplot(data=df, x="race");
plt.xticks(rotation=45);

# %% [markdown]
# #### Check the count of person in each "salary" levels by races and visualize it with countplot

# %%
df.groupby("race")["salary"].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="race", hue="salary");
plt.xticks(rotation=45);

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot

# %%
perc_race = df.groupby("race")["salary"].value_counts(normalize=True) * 100
perc_race
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    88.424
#                     >50K     11.576
# Asian-Pac-Islander  <=50K    73.410
#                     >50K     26.590
# Black               <=50K    87.604
#                     >50K     12.396
# Other               <=50K    90.775
#                     >50K      9.225
# White               <=50K    74.402
#                     >50K     25.598
# Name: salary, dtype: float64

# %%
fig, ax = plt.subplots(2, 3, figsize=(15,9));


ax[0][0].pie(perc_race[0:2],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[0][0].set_title(perc_race.index[0][0],fontsize=12)
ax[0][0].set_ylabel("salary", fontsize=10)

ax[0][1].pie(perc_race[2:4],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[0][1].set_title(perc_race.index[2][0],fontsize=12)
ax[0][1].set_ylabel("salary", fontsize=10)


ax[0][2].pie(perc_race[4:6],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[0][2].set_title(perc_race.index[4][0],fontsize=12)
ax[0][2].set_ylabel("salary", fontsize=10)


ax[1][0].pie(perc_race[6:8],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[1][0].set_title(perc_race.index[6][0],fontsize=12)
ax[1][0].set_ylabel("salary", fontsize=10)


ax[1][1].pie(perc_race[8:10],
            labels=["<=50K", ">50K"],
            autopct= "%.2f%%",
            colors=["pink","lightskyblue"]);
ax[1][1].set_title(perc_race.index[8][0],fontsize=12)
ax[1][1].set_ylabel("salary", fontsize=10)



ax[1,2].axis("off");

# %% [markdown]
# #### Check the count of person in each races by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
sns.countplot(data=df, x="salary", hue="race");

# %% [markdown]
# #### Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot

# %%
df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
df_perc_race_by_salary = pd.DataFrame(df.groupby("salary")["race"].value_counts(normalize=True))
df_perc_race_by_salary.rename({"race": "percentage"}, axis=1, inplace=True)
df_perc_race_by_salary.reset_index(level=[0,1], inplace=True)
df_perc_race_by_salary.sort_values(["salary", "race"], inplace=True)
df_perc_race_by_salary
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %%
fig,ax = plt.subplots()

sns.barplot(data=df_perc_race_by_salary, x="salary", y="percentage", hue="race");

for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.3f');

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. About 25% of 'White' and 'Asian-Pac-Islander' people earn more than 50K per year, while only around 10% of people from all other races ('Amer-Indian-Eskimo', 'Black', 'Other') earn above 50K per year.

# %% [markdown]
# ## gender

# %%
df.sex.value_counts(dropna=False)
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
sns.countplot(data=df, x="sex");

# %% [markdown]
# #### Check the count of person in each "salary" levels by gender and visualize it with countplot

# %%
df.groupby("sex")["salary"].value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="sex", hue="salary");

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot

# %%
perc_salary_by_gender = df.groupby("sex")["salary"].value_counts(normalize=True)
perc_salary_by_gender
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6));

ax[0].pie(x=perc_salary_by_gender[0:2],
          labels=["<=50K", ">50K"],
          colors=["pink", "skyblue"],
         autopct="%.2f");
ax[0].set_title("Female");
ax[0].set_ylabel("salary", fontsize=10)

ax[1].pie(x=perc_salary_by_gender[2:4],
          labels=["<=50K", ">50K"],
         colors=["pink", "skyblue"],
          autopct="%.2f");
ax[1].set_title("Male");
ax[1].set_ylabel("salary", fontsize=10);

# %% [markdown]
# #### Check the count of person in each gender by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["sex"].value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
sns.countplot(data=df, x="salary", hue="sex");

# %% [markdown]
# #### Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot

# %%
perc_gender_by_salary = df.groupby("salary")["sex"].value_counts(normalize=True)
perc_gender_by_salary
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6));

ax[0].pie(x=perc_gender_by_salary[0:2],
          labels=["Male", ">Female"],
          colors=["pink", "skyblue"],
         autopct="%.2f");
ax[0].set_title("<=50K");
ax[0].set_ylabel("gender", fontsize=10);

ax[1].pie(x=perc_gender_by_salary[2:4],
          labels=["Male", ">Female"],
         colors=["pink", "skyblue"],
          autopct="%.2f");
ax[1].set_title(">50K");
ax[1].set_ylabel("gender", fontsize=10);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. While 31% of male participants earn more than 50K per year, only 11% of female partipcants earn more than 50K. So, men appear to be earning more than women.

# %% [markdown]
# ## native_country

# %% [markdown]
# #### Check the count of person in each categories and visualize it with countplot

# %%
df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
sns.countplot(data=df, x="native_country");
plt.xticks(rotation=90);

# %% [markdown]
# #### Replace the value "?" to the value "Unknown"

# %%
df.native_country.replace("?", "Unknown", inplace=True)

# %% [markdown]
# #### Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

df["native_country_summary"] = df.native_country.transform(mapping_native_country)

df.sample(2)
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 4073    33   Private  131776     Bachelors         13.000            Divorced
# 24526   50   Private  174655  Some-college         10.000  Married-civ-spouse
#
#            occupation relationship   race     sex  capital_gain  capital_loss  \
# 4073   Prof-specialty    Unmarried  White  Female           914             0
# 24526           Sales      Husband  White    Male             0             0
#
#        hours_per_week native_country salary           edu_level  \
# 4073               40        Germany  <=50K    high_level_grade
# 24526              45  United-States   >50K  medium_level_grade
#
#       marital_status_summary native_country_summary
# 4073               unmarried                 Others
# 24526                married                     US

# %% [markdown]
# #### Visualize the count of person in each new categories (US, Others)

# %%
df["native_country_summary"].value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country_summary, dtype: int64

# %%
sns.countplot(data=df, x="native_country_summary");

# %% [markdown]
# #### Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot

# %%
df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
sns.countplot(data=df, x="native_country_summary", hue="salary");

# %% [markdown]
# #### Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately

# %%
perc_salary_by_country = df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
perc_salary_by_country
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6));

ax[0].pie(x=perc_salary_by_country[0:2],
          labels=["<=50K", ">50K"],
          colors=["pink", "skyblue"],
         autopct="%.2f");
ax[0].set_title("Others");
ax[0].set_ylabel("salary", fontsize=10)

ax[1].pie(x=perc_salary_by_country[2:4],
          labels=["<=50K", ">50K"],
         colors=["pink", "skyblue"],
          autopct="%.2f");
ax[1].set_title("US");
ax[1].set_ylabel("salary", fontsize=10);

# %% [markdown]
# #### Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
sns.countplot(data=df, x="salary", hue="native_country_summary");

# %% [markdown]
# #### Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately

# %%
perc_country_by_salary = df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
perc_country_by_salary
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6));

ax[0].pie(x=perc_country_by_salary[0:2],
          labels=["US", "Others"],
          colors=["pink", "skyblue"],
         autopct="%.2f");
ax[0].set_title("<=50K");
ax[0].set_ylabel("salary", fontsize=10)

ax[1].pie(x=perc_country_by_salary[2:4],
          labels=["US", "Others"],
         colors=["pink", "skyblue"],
          autopct="%.2f");
ax[1].set_title(">50K");
ax[1].set_ylabel("salary", fontsize=10);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**
#
# **Result :**
# 1. In terms of the native country, the numbers of US participants is significantly higher than the numbers of Other participants. So, the data doesn't actually provide very clear insights to make comparisons.
# 2. Yet, with the data provided, it can be seen that a higher percentage of US participants (25%) earn >50K annulayy compared to Other participants (20%).

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
avr_age = df.groupby(["salary", "sex"]).age.mean()
avr_age
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
fig, ax = plt.subplots();

ax = avr_age.plot(kind="bar", xlabel="salary,gender");

ax.bar_label(ax.containers[0], fmt="%.2f");

# %%
# pd.DataFrame(avr_age).reset_index().rename(columns={"sex":"gender"})

df_avr_age = avr_age.to_frame().reset_index().rename(columns={"sex":"gender"})
df_avr_age
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
fig, ax = plt.subplots()
sns.barplot(data=df_avr_age, x="salary", y="age", hue="gender");

for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.2f');

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
high_income_US_perc = df[(df.salary == ">50K") & (df.native_country_summary == "US")].workclass.value_counts(normalize=True) * 100
high_income_US_perc
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
fig, ax = plt.subplots()
sns.barplot(x=high_income_US_perc.index, y=high_income_US_perc.values);

plt.xticks(rotation=45)

for i in ax.containers:
    ax.bar_label(i, size=10, fmt='%.2f');

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# df.loc[df.duplicated()]
# df[df.duplicated()].index
# df.iloc[df[df.duplicated()].index]
# df.drop_duplicates(inplace = True)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# To fill the missing values in "education_num" column

df1=df.copy()

my_dict = {}
for (a, b) in df1.groupby("education_num")["education"].value_counts().index :
    my_dict[b]=a

df1.education_num=df1.education
df1["education_num"].replace(my_dict, inplace=True)


df1.sample()
# Out:
#       age         workclass  fnlwgt  education  education_num  \
# 9021   34  Self-emp-not-inc  313729  Bachelors         13.000
#
#           marital_status occupation relationship   race   sex  capital_gain  \
# 9021  Married-civ-spouse      Sales      Husband  White  Male             0
#
#       capital_loss  hours_per_week native_country salary         edu_level  \
# 9021             0              60  United-States   >50K  high_level_grade
#
#      marital_status_summary
# 9021                married

# %%
# Check if the Dataset has any Question Mark "?"

print("Number of '?'s in the dataset:", "\n")

for col in df.columns:
    if (df[col] == '?').sum() > 0:
        print(f"{col} : {(df[col] == '?').sum()}")  # len(df[df[col] == '?']) can replace (df[col] == '?').sum()
# Out:
# Number of '?'s in the dataset:
#
# workclass : 1836
# occupation : 1843
# native_country : 582

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
